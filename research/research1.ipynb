# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd

# %matplotlib inline

# %%
df = pd.read_csv("../csv_data/stocks.csv")

# %%
df.shape
# Out:
# (41266, 502)

# %%
df.head()
# Out:
#          DATE      SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# 0  1491226200  2363.6101     42.3300     143.6800     129.6300      82.040
# 1  1491226260  2364.1001     42.3600     143.7000     130.3200      82.080
# 2  1491226320  2362.6799     42.3100     143.6901     130.2250      82.030
# 3  1491226380  2364.3101     42.3700     143.6400     130.0729      82.000
# 4  1491226440  2364.8501     42.5378     143.6600     129.8800      82.035
#
#    NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  ...  NYSE.WYN  NYSE.XEC  \
# 0    102.2300      85.2200       59.760       121.52  ...    84.370   119.035
# 1    102.1400      85.6500       59.840       121.48  ...    84.370   119.035
# 2    102.2125      85.5100       59.795       121.93  ...    84.585   119.260
# 3    102.1400      85.4872       59.620       121.44  ...    84.460   119.260
# 4    102.0600      85.7001       59.620       121.60  ...    84.470   119.610
#
# ...

# %%
df['DATE'].dtypes
# Out:
# dtype('int64')

# %%
df['DATE'] = pd.to_datetime(df['DATE'],unit='s')

# %%
df['DATE'].head()
# Out:
# 0   2017-04-03 13:30:00
# 1   2017-04-03 13:31:00
# 2   2017-04-03 13:32:00
# 3   2017-04-03 13:33:00
# 4   2017-04-03 13:34:00
# Name: DATE, dtype: datetime64[ns]

# %%
df.index = df['DATE']

# %%
df.head()
# Out:
#                                    DATE      SP500  NASDAQ.AAL  NASDAQ.AAPL  \
# DATE
# 2017-04-03 13:30:00 2017-04-03 13:30:00  2363.6101     42.3300     143.6800
# 2017-04-03 13:31:00 2017-04-03 13:31:00  2364.1001     42.3600     143.7000
# 2017-04-03 13:32:00 2017-04-03 13:32:00  2362.6799     42.3100     143.6901
# 2017-04-03 13:33:00 2017-04-03 13:33:00  2364.3101     42.3700     143.6400
# 2017-04-03 13:34:00 2017-04-03 13:34:00  2364.8501     42.5378     143.6600
#
#                      NASDAQ.ADBE  NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  \
# DATE
# 2017-04-03 13:30:00     129.6300      82.040    102.2300      85.2200
# 2017-04-03 13:31:00     130.3200      82.080    102.1400      85.6500
# 2017-04-03 13:32:00     130.2250      82.030    102.2125      85.5100
# 2017-04-03 13:33:00     130.0729      82.000    102.1400      85.4872
# 2017-04-03 13:34:00     129.8800      82.035    102.0600      85.7001
#
#                      NASDAQ.AKAM  NASDAQ.ALXN  ...  NYSE.WYN  NYSE.XEC  \
# ...

# %%
df.drop('DATE',axis = 1,inplace=True)

# %%
df.head()
# Out:
#                          SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  \
# DATE
# 2017-04-03 13:30:00  2363.6101     42.3300     143.6800     129.6300
# 2017-04-03 13:31:00  2364.1001     42.3600     143.7000     130.3200
# 2017-04-03 13:32:00  2362.6799     42.3100     143.6901     130.2250
# 2017-04-03 13:33:00  2364.3101     42.3700     143.6400     130.0729
# 2017-04-03 13:34:00  2364.8501     42.5378     143.6600     129.8800
#
#                      NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  \
# DATE
# 2017-04-03 13:30:00      82.040    102.2300      85.2200       59.760
# 2017-04-03 13:31:00      82.080    102.1400      85.6500       59.840
# 2017-04-03 13:32:00      82.030    102.2125      85.5100       59.795
# 2017-04-03 13:33:00      82.000    102.1400      85.4872       59.620
# 2017-04-03 13:34:00      82.035    102.0600      85.7001       59.620
#
#                      NASDAQ.ALXN  NASDAQ.AMAT  ...  NYSE.WYN  NYSE.XEC  \
# ...

# %%
df.tail()
# Out:
#                        SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  \
# DATE
# 2017-08-31 19:56:00  2472.22       44.72       164.11      155.090
# 2017-08-31 19:57:00  2471.77       44.73       164.12      155.160
# 2017-08-31 19:58:00  2470.03       44.74       164.01      155.065
# 2017-08-31 19:59:00  2471.49       44.71       163.88      154.960
# 2017-08-31 20:00:00  2471.49       44.74       163.98      155.160
#
#                      NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  \
# DATE
# 2017-08-31 19:56:00       83.67     106.565       114.49       47.150
# 2017-08-31 19:57:00       83.65     106.590       114.52       47.150
# 2017-08-31 19:58:00       83.62     106.520       114.47       47.150
# 2017-08-31 19:59:00       83.58     106.400       114.33       47.135
# 2017-08-31 20:00:00       83.69     106.470       114.46       47.150
#
#                      NASDAQ.ALXN  NASDAQ.AMAT  ...  NYSE.WYN  NYSE.XEC  \
# DATE                                           ...
# ...

# %%
from sklearn.cluster import KMeans

# %%
x=df.iloc[:,:]

# %%
x
# Out:
#                          SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  \
# DATE
# 2017-04-03 13:30:00  2363.6101     42.3300     143.6800     129.6300
# 2017-04-03 13:31:00  2364.1001     42.3600     143.7000     130.3200
# 2017-04-03 13:32:00  2362.6799     42.3100     143.6901     130.2250
# 2017-04-03 13:33:00  2364.3101     42.3700     143.6400     130.0729
# 2017-04-03 13:34:00  2364.8501     42.5378     143.6600     129.8800
# ...                        ...         ...          ...          ...
# 2017-08-31 19:56:00  2472.2200     44.7200     164.1100     155.0900
# 2017-08-31 19:57:00  2471.7700     44.7300     164.1200     155.1600
# 2017-08-31 19:58:00  2470.0300     44.7400     164.0100     155.0650
# 2017-08-31 19:59:00  2471.4900     44.7100     163.8800     154.9600
# 2017-08-31 20:00:00  2471.4900     44.7400     163.9800     155.1600
#
#                      NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  \
# DATE
# ...

# %%
wcss=[]
for i in range(1,15):
    kmean=KMeans(n_clusters=i,init='k-means++',random_state=30)
    kmean.fit(x)
    wcss.append(kmean.inertia_)

# %%
plt.plot(range(1,15)  , wcss)

# %%
kmean1= KMeans(n_clusters=5 ,init = 'k-means++' , random_state=30)
kmean1.fit_predict(x)
# Out:
# array([4, 4, 4, ..., 0, 0, 0])

# %%
x['cluster number'] = kmean1.fit_predict(x)

# %%
x
# Out:
#                          SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  \
# DATE
# 2017-04-03 13:30:00  2363.6101     42.3300     143.6800     129.6300
# 2017-04-03 13:31:00  2364.1001     42.3600     143.7000     130.3200
# 2017-04-03 13:32:00  2362.6799     42.3100     143.6901     130.2250
# 2017-04-03 13:33:00  2364.3101     42.3700     143.6400     130.0729
# 2017-04-03 13:34:00  2364.8501     42.5378     143.6600     129.8800
# ...                        ...         ...          ...          ...
# 2017-08-31 19:56:00  2472.2200     44.7200     164.1100     155.0900
# 2017-08-31 19:57:00  2471.7700     44.7300     164.1200     155.1600
# 2017-08-31 19:58:00  2470.0300     44.7400     164.0100     155.0650
# 2017-08-31 19:59:00  2471.4900     44.7100     163.8800     154.9600
# 2017-08-31 20:00:00  2471.4900     44.7400     163.9800     155.1600
#
#                      NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  \
# DATE
# ...

# %%
x[x['cluster number'] ==4]
# Out:
#                          SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  \
# DATE
# 2017-04-03 13:30:00  2363.6101     42.3300     143.6800     129.6300
# 2017-04-03 13:31:00  2364.1001     42.3600     143.7000     130.3200
# 2017-04-03 13:32:00  2362.6799     42.3100     143.6901     130.2250
# 2017-04-03 13:33:00  2364.3101     42.3700     143.6400     130.0729
# 2017-04-03 13:34:00  2364.8501     42.5378     143.6600     129.8800
# ...                        ...         ...          ...          ...
# 2017-04-27 18:40:00  2390.1899     43.7400     143.7900     133.4700
# 2017-04-27 18:41:00  2389.8999     43.7700     143.7700     133.4300
# 2017-04-27 18:42:00  2390.3201     43.7550     143.7400     133.4250
# 2017-04-27 18:43:00  2390.5901     43.7550     143.7835     133.4700
# 2017-04-27 18:44:00  2390.4600     43.8200     143.7950     133.4700
#
#                      NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  \
# DATE
# ...

# %%
x[x['cluster number'] ==3]
# Out:
#                          SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  \
# DATE
# 2017-05-23 13:30:00  2398.4099     46.2700     154.9000      139.160
# 2017-05-23 13:31:00  2396.8601     46.3115     154.6320      139.376
# 2017-05-23 13:32:00  2397.0200     46.1100     154.0000      139.490
# 2017-05-23 13:33:00  2397.0901     46.0650     154.1800      139.550
# 2017-05-23 13:34:00  2396.3799     46.1500     154.2000      139.250
# ...                        ...         ...          ...          ...
# 2017-07-07 15:30:00  2421.7400     53.0250     143.9850      142.130
# 2017-07-07 15:31:00  2421.7100     53.0400     143.9600      142.040
# 2017-07-07 15:32:00  2421.2700     53.0100     144.0221      142.000
# 2017-07-07 15:33:00  2421.9800     53.0550     144.0300      142.060
# 2017-07-07 15:34:00  2422.4199     53.0500     144.0700      142.200
#
#                      NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  \
# DATE
# ...

# %%
x[x['cluster number'] ==2]
# Out:
#                          SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  \
# DATE
# 2017-07-07 15:35:00  2423.3201      53.140     144.0870     142.3200
# 2017-07-07 15:36:00  2423.1899      53.180     144.1400     142.3800
# 2017-07-07 15:37:00  2423.5801      53.090     144.0700     142.3450
# 2017-07-07 15:38:00  2423.5500      53.060     144.0600     142.3000
# 2017-07-07 15:39:00  2423.2700      53.100     144.1144     142.3554
# ...                        ...         ...          ...          ...
# 2017-08-08 19:56:00  2473.0500      49.985     159.8500     147.7700
# 2017-08-08 19:57:00  2473.7700      49.980     159.8850     147.7300
# 2017-08-08 19:58:00  2474.3101      50.000     159.9900     147.8450
# 2017-08-08 19:59:00  2474.8601      50.010     159.9700     147.7900
# 2017-08-08 20:00:00  2474.8601      50.000     160.0800     147.8100
#
#                      NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  \
# DATE
# ...

# %%
x[x['cluster number'] ==1]
# Out:
#                          SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  \
# DATE
# 2017-04-27 18:45:00  2390.6399      43.850       143.80     133.4600
# 2017-04-27 18:46:00  2390.5701      43.845       143.77     133.4565
# 2017-04-27 18:47:00  2390.5701      43.800       143.77     133.4580
# 2017-04-27 18:48:00  2390.8501      43.795       143.78     133.4500
# 2017-04-27 18:49:00  2390.5901      43.820       143.79     133.4300
# ...                        ...         ...          ...          ...
# 2017-05-22 19:56:00  2395.0200      46.205       154.00     138.9250
# 2017-05-22 19:57:00  2394.6599      46.200       153.97     138.9200
# 2017-05-22 19:58:00  2394.0300      46.190       153.94     138.9000
# 2017-05-22 19:59:00  2393.8899      46.200       153.90     138.8500
# 2017-05-22 20:00:00  2393.8899      46.210       153.99     138.8600
#
#                      NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  \
# DATE
# ...

# %%
x[x['cluster number'] ==0]
# Out:
#                          SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  \
# DATE
# 2017-08-09 13:30:00  2465.4399     49.7400       159.25      146.680
# 2017-08-09 13:31:00  2464.7400     49.6400       159.71      146.860
# 2017-08-09 13:32:00  2465.5701     49.5271       159.86      146.560
# 2017-08-09 13:33:00  2467.8401     49.4950       159.64      146.660
# 2017-08-09 13:34:00  2468.0901     49.2800       159.86      146.700
# ...                        ...         ...          ...          ...
# 2017-08-31 19:56:00  2472.2200     44.7200       164.11      155.090
# 2017-08-31 19:57:00  2471.7700     44.7300       164.12      155.160
# 2017-08-31 19:58:00  2470.0300     44.7400       164.01      155.065
# 2017-08-31 19:59:00  2471.4900     44.7100       163.88      154.960
# 2017-08-31 20:00:00  2471.4900     44.7400       163.98      155.160
#
#                      NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  \
# DATE
# ...

# %%
from sklearn.cluster import MiniBatchKMeans
minibatch_kmean = MiniBatchKMeans(n_clusters=5)
minibatch_kmean.fit(x)
# Out:
# d:\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1043: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 3072 or by setting the environment variable OMP_NUM_THREADS=4
#   warnings.warn(
# MiniBatchKMeans(n_clusters=5)

# %%
x['MiniBatch_cluster number']=minibatch_kmean.fit_predict(x)
# Out:
# d:\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1043: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 3072 or by setting the environment variable OMP_NUM_THREADS=4
#   warnings.warn(

# %%
from  sklearn.cluster import DBSCAN

# %%
x
# Out:
#                          SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  \
# DATE
# 2017-04-03 13:30:00  2363.6101     42.3300     143.6800     129.6300
# 2017-04-03 13:31:00  2364.1001     42.3600     143.7000     130.3200
# 2017-04-03 13:32:00  2362.6799     42.3100     143.6901     130.2250
# 2017-04-03 13:33:00  2364.3101     42.3700     143.6400     130.0729
# 2017-04-03 13:34:00  2364.8501     42.5378     143.6600     129.8800
# ...                        ...         ...          ...          ...
# 2017-08-31 19:56:00  2472.2200     44.7200     164.1100     155.0900
# 2017-08-31 19:57:00  2471.7700     44.7300     164.1200     155.1600
# 2017-08-31 19:58:00  2470.0300     44.7400     164.0100     155.0650
# 2017-08-31 19:59:00  2471.4900     44.7100     163.8800     154.9600
# 2017-08-31 20:00:00  2471.4900     44.7400     163.9800     155.1600
#
#                      NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  \
# DATE
# ...

# %%
dbscan_cluster=DBSCAN(eps=1, min_samples=3)

# %%
x['dbscan_cluster number']=dbscan_cluster.fit_predict(x)

# %%
x
# Out:
#                          SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  \
# DATE
# 2017-04-03 13:30:00  2363.6101     42.3300     143.6800     129.6300
# 2017-04-03 13:31:00  2364.1001     42.3600     143.7000     130.3200
# 2017-04-03 13:32:00  2362.6799     42.3100     143.6901     130.2250
# 2017-04-03 13:33:00  2364.3101     42.3700     143.6400     130.0729
# 2017-04-03 13:34:00  2364.8501     42.5378     143.6600     129.8800
# ...                        ...         ...          ...          ...
# 2017-08-31 19:56:00  2472.2200     44.7200     164.1100     155.0900
# 2017-08-31 19:57:00  2471.7700     44.7300     164.1200     155.1600
# 2017-08-31 19:58:00  2470.0300     44.7400     164.0100     155.0650
# 2017-08-31 19:59:00  2471.4900     44.7100     163.8800     154.9600
# 2017-08-31 20:00:00  2471.4900     44.7400     163.9800     155.1600
#
#                      NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  \
# DATE
# ...

# %%
dbscan_cluster.fit_predict(x)
# Out:
# array([-1, -1, -1, ..., -1, -1, -1], dtype=int64)

# %%
df.columns[:-3]
# Out:
# Index(['SP500', 'NASDAQ.AAL', 'NASDAQ.AAPL', 'NASDAQ.ADBE', 'NASDAQ.ADI',
#        'NASDAQ.ADP', 'NASDAQ.ADSK', 'NASDAQ.AKAM', 'NASDAQ.ALXN',
#        'NASDAQ.AMAT',
#        ...
#        'NYSE.WYN', 'NYSE.XEC', 'NYSE.XEL', 'NYSE.XL', 'NYSE.XOM', 'NYSE.XRX',
#        'NYSE.XYL', 'NYSE.YUM', 'NYSE.ZBH', 'NYSE.ZTS'],
#       dtype='object', length=501)

# %%
import seaborn as sns

# %%
all_stocks=[]
for i in df.columns[:-3]:
    all_stocks.append(i)

# %%
centroids = kmean1.cluster_centers_
plt.scatter(x.values[:,0],x.values[:,-3], c = kmean1.labels_, cmap ="rainbow")
plt.title(x.iloc[0].index[0])
plt.show()

# %%
kmean1.labels_
# Out:
# array([4, 4, 4, ..., 0, 0, 0])

# %%
x.values[:,0]
# Out:
# array([2363.6101, 2364.1001, 2362.6799, ..., 2470.03  , 2471.49  ,
#        2471.49  ])

# %%
x.values[:,-3]
# Out:
# array([4., 4., 4., ..., 0., 0., 0.])

# %%
k=5
sns.scatterplot(x=x.values[:,0],y=x.values[:,1], data=x, 
                palette=sns.color_palette("bright",k),
                hue='cluster number', size_order=[1,0],
                legend="brief").set_title(f'Clustering (k={str(k)}) {df.columns[0]} vs  {df.columns[1]}')
# Out:
# Text(0.5, 1.0, 'Clustering (k=5) SP500 vs  NASDAQ.AAL')

# %%
x.head()
# Out:
#                          SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  \
# DATE
# 2017-04-03 13:30:00  2363.6101     42.3300     143.6800     129.6300
# 2017-04-03 13:31:00  2364.1001     42.3600     143.7000     130.3200
# 2017-04-03 13:32:00  2362.6799     42.3100     143.6901     130.2250
# 2017-04-03 13:33:00  2364.3101     42.3700     143.6400     130.0729
# 2017-04-03 13:34:00  2364.8501     42.5378     143.6600     129.8800
#
#                      NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  \
# DATE
# 2017-04-03 13:30:00      82.040    102.2300      85.2200       59.760
# 2017-04-03 13:31:00      82.080    102.1400      85.6500       59.840
# 2017-04-03 13:32:00      82.030    102.2125      85.5100       59.795
# 2017-04-03 13:33:00      82.000    102.1400      85.4872       59.620
# 2017-04-03 13:34:00      82.035    102.0600      85.7001       59.620
#
#                      NASDAQ.ALXN  NASDAQ.AMAT  ...  NYSE.XL  NYSE.XOM  \
# ...

# %%
data1 = df.copy()
cor = data1.corr()

# %%
cor
# Out:
#                              SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  \
# SP500                     1.000000    0.712007     0.553332     0.909061
# NASDAQ.AAL                0.712007    1.000000     0.082065     0.542213
# NASDAQ.AAPL               0.553332    0.082065     1.000000     0.714578
# NASDAQ.ADBE               0.909061    0.542213     0.714578     1.000000
# NASDAQ.ADI                0.219471    0.209446     0.264269     0.259282
# ...                            ...         ...          ...          ...
# NYSE.ZBH                  0.143752    0.588241    -0.580055    -0.067235
# NYSE.ZTS                  0.813459    0.753567     0.442600     0.776052
# cluster number           -0.441831    0.004287    -0.758361    -0.594812
# MiniBatch_cluster number -0.185866    0.242873    -0.616449    -0.361391
# dbscan_cluster number     0.051712   -0.009525     0.163261     0.116046
#
#                           NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  \
# ...

# %%
cor_dt = pd.DataFrame(data=cor.values, columns=cor.index, index = cor.index)
cor_dt.head()
# Out:
#                 SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# SP500        1.000000    0.712007     0.553332     0.909061    0.219471
# NASDAQ.AAL   0.712007    1.000000     0.082065     0.542213    0.209446
# NASDAQ.AAPL  0.553332    0.082065     1.000000     0.714578    0.264269
# NASDAQ.ADBE  0.909061    0.542213     0.714578     1.000000    0.259282
# NASDAQ.ADI   0.219471    0.209446     0.264269     0.259282    1.000000
#
#              NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  NASDAQ.AMAT  \
# SP500          0.562785     0.834350    -0.690018     0.450572     0.752814
# NASDAQ.AAL     0.245801     0.610881    -0.441142     0.009581     0.681863
# NASDAQ.AAPL    0.265641     0.645233    -0.712522     0.326712     0.545541
# NASDAQ.ADBE    0.476496     0.872353    -0.759604     0.488717     0.733609
# NASDAQ.ADI    -0.085074     0.470756    -0.323603    -0.409747     0.504019
#
# ...

# %%
cor_dt[cor_dt['NASDAQ.AAL'].values > 0.80][:5]
# Out:
#                 SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# NASDAQ.AAL   0.712007    1.000000     0.082065     0.542213    0.209446
# NASDAQ.AMZN  0.834878    0.803319     0.370111     0.730719    0.386619
# NASDAQ.EXPE  0.892177    0.812206     0.379622     0.818384    0.218189
# NASDAQ.HAS   0.473669    0.832713    -0.274890     0.251696    0.252954
# NYSE.CMI     0.720325    0.810391     0.088336     0.528227    0.206259
#
#              NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  NASDAQ.AMAT  \
# NASDAQ.AAL     0.245801     0.610881    -0.441142     0.009581     0.681863
# NASDAQ.AMZN    0.252712     0.828757    -0.648854     0.059345     0.897693
# NASDAQ.EXPE    0.369697     0.834440    -0.707045     0.296553     0.817588
# NASDAQ.HAS    -0.030201     0.394658    -0.206013    -0.208923     0.530874
# NYSE.CMI       0.179664     0.577301    -0.458993     0.140823     0.690999
#
# ...

# %%
sns.heatmap(cor_dt[cor_dt['NASDAQ.AAL'].values > 0.80][:5])
# Out:
# <AxesSubplot:>

# %%
data.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13696\3993293784.py in <module>
# ----> 1 data.shape
#
# NameError: name 'data' is not defined

# %%
by_kmeans=x.groupby('cluster number')

# %%
by_kmeans.first()
# Out:
#                     SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# cluster number
# 0               2465.4399       49.74      159.250       146.68       78.50
# 1               2390.6399       43.85      143.800       133.46       77.86
# 2               2423.3201       53.14      144.087       142.32       78.17
# 3               2398.4099       46.27      154.900       139.16       82.28
# 4               2363.6101       42.33      143.680       129.63       82.04
#
#                 NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  \
# cluster number
# 0                   108.51       107.74      47.1800      136.080
# 1                   105.25        90.74      59.1650      126.950
# 2                   105.17       103.76      49.6199      123.225
# 3                    99.37       113.20      47.8600      111.510
# 4                   102.23        85.22      59.7600      121.520
#
#                 NASDAQ.AMAT  ...  NYSE.XEL  NYSE.XL  NYSE.XOM  NYSE.XRX  \
# ...

# %%
by_kmeans.mean()
# Out:
#                       SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# cluster number
# 0               2450.568972   46.273472   160.115209   150.240076   79.291167
# 1               2389.233746   45.095788   151.058637   135.620393   78.212789
# 2               2463.893554   51.720914   151.091955   146.943884   79.563809
# 3               2428.456903   49.275774   148.633802   141.543622   80.548170
# 4               2359.072504   43.773527   142.985481   130.744082   78.729621
#
#                 NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  \
# cluster number
# 0               106.639849   110.226624    46.017857   136.295053
# 1                99.117908    96.221768    51.975294   123.320012
# 2               107.420428   108.888832    49.394391   131.058861
# 3               101.801403   107.794247    49.102019   112.117511
# 4               102.567833    86.827594    59.523315   118.481349
#
# ...

# %% [markdown]
# ## Applying PCA Approach

# %% [markdown]
# #### Scaling the Orignal data

# %%
df1= pd.read_csv('../csv_data/stocks.csv')

# %%
from sklearn.preprocessing import StandardScaler
features = df1.values
sc = StandardScaler()
X_scaled = sc.fit_transform(features)

# %%
X_scaled[:5]
# Out:
# array([[-1.70648886, -1.46442566, -1.65013444, ..., -1.95578373,
#          0.10281519, -2.04188417],
#        [-1.70647316, -1.45203837, -1.64093012, ..., -1.98549977,
#          0.06179505, -2.04188417],
#        [-1.70645747, -1.4879413 , -1.65627065, ..., -1.98302344,
#          0.04931066, -2.03740234],
#        [-1.70644177, -1.44672953, -1.63786201, ..., -1.95083106,
#          0.04931066, -2.03292051],
#        [-1.70642607, -1.43307822, -1.58637916, ..., -1.94340205,
#          0.04841892, -2.07475093]])

# %%
X_scaled.shape
# Out:
# (41266, 502)

# %% [markdown]
# ### Looking for best components for PCA

# %%
from sklearn.decomposition import PCA

pca = PCA().fit(X_scaled)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()

# %%
np.cumsum(pca.explained_variance_ratio_)
# Out:
# array([0.47212951, 0.64385235, 0.76360029, 0.81195852, 0.84991719,
#        0.87788756, 0.89781926, 0.91082999, 0.92129062, 0.92877768,
#        0.93558946, 0.94134857, 0.9459725 , 0.95045307, 0.95449759,
#        0.95793844, 0.96124101, 0.96379857, 0.96611078, 0.96827586,
#        0.97014547, 0.97170516, 0.97317647, 0.97450058, 0.97576367,
#        0.97695774, 0.97805254, 0.97909091, 0.980004  , 0.98083515,
#        0.98165436, 0.98244405, 0.98313914, 0.98381497, 0.98443395,
#        0.98501588, 0.98557063, 0.98609748, 0.98659348, 0.98708171,
#        0.98752751, 0.98795549, 0.98834636, 0.98872556, 0.9890831 ,
#        0.98941317, 0.98973175, 0.9900439 , 0.99033054, 0.9906071 ,
#        0.99087721, 0.99114077, 0.99139834, 0.99164465, 0.99188437,
#        0.99211054, 0.99233415, 0.99254147, 0.9927409 , 0.9929347 ,
#        0.99312528, 0.99330381, 0.99347573, 0.99364303, 0.99380612,
#        0.99396547, 0.99412078, 0.99427234, 0.99441993, 0.99455846,
# ...

# %%
pca.components_
# Out:
# array([[-6.41156025e-02, -6.10062544e-02, -3.91275462e-02, ...,
#         -6.22290774e-02,  2.49838660e-03, -5.14967334e-02],
#        [ 1.34595402e-02, -1.78358090e-02, -6.42813334e-02, ...,
#         -2.03673939e-02, -8.12466492e-02, -5.94523733e-02],
#        [ 2.57051822e-04, -1.36898239e-02, -3.97645497e-02, ...,
#          2.10932582e-02, -6.63016753e-02,  2.36739932e-02],
#        ...,
#        [-2.55919925e-02, -6.45887436e-03, -4.98671613e-03, ...,
#         -1.25612712e-02,  5.36401127e-03,  2.19470530e-02],
#        [-1.71065399e-01,  3.89353644e-03,  1.77873325e-02, ...,
#          2.66729437e-02,  5.57436923e-03, -1.11256221e-02],
#        [ 9.54579051e-01, -5.59753688e-03, -1.20086387e-02, ...,
#         -8.80606272e-03,  1.33290642e-03, -6.09358558e-03]])

# %% [markdown]
# #### Apply PCA to reduce the number of dimensions from 502 to 2 dimensions for better data visualization.

# %%
pca = PCA(n_components=2)
pca.fit(X_scaled)

X_transformed = pca.transform(X_scaled)

X_retransformed = pca.inverse_transform(X_transformed)

# %%
X_transformed.shape
# Out:
# (41266, 2)

# %%
X_retransformed.shape
# Out:
# (41266, 502)

# %% [markdown]
# ## 2) Setting cluster on the Scaled Data using Kmeans++

# %%
wcss=[]
for i in range(1, 21):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 121)
    kmeans.fit(X_transformed)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 21), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Mean Squared Errors')
plt.figure(figsize=(10,8))
plt.show()

# %% [markdown]
# #### AS we can see k=5 is optimum

# %% [markdown]
# #### Applying Kmeans clustering finally for k=5

# %%
k_means_plus = KMeans(n_clusters=5,random_state=121,init='k-means++')
k_means_plus.fit(X_transformed)
y_kmeans = k_means_plus.fit_predict(X_transformed)
labels = k_means_plus.labels_

# %%
labels
# Out:
# array([0, 0, 0, ..., 2, 2, 2])

# %%
X_transformed[y_kmeans == 0, 0]
# Out:
# array([25.64715405, 25.74447983, 25.66169481, ..., 18.74227681,
#        18.71888896, 18.6956676 ])

# %%
len(y_kmeans)
# Out:
# 41266

# %%
y_kmeans.shape
# Out:
# (41266,)

# %%
X_transformed
# Out:
# array([[ 25.64715405,   9.99154156],
#        [ 25.74447983,   9.87809253],
#        [ 25.66169481,   9.81134664],
#        ...,
#        [-22.85875597,  13.3380181 ],
#        [-22.7057793 ,  13.42820228],
#        [-22.81349985,  13.37277083]])

# %%
plt.scatter(X_transformed[y_kmeans == 0, 0], X_transformed[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X_transformed[y_kmeans == 1, 0], X_transformed[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X_transformed[y_kmeans == 2, 0], X_transformed[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(X_transformed[y_kmeans == 3, 0], X_transformed[y_kmeans == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(X_transformed[y_kmeans == 4, 0], X_transformed[y_kmeans == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
plt.title('Clusters of stocks')
plt.xlabel('Principal Component (1)')
plt.ylabel('Principal Component (2)')
plt.legend()
plt.show()

# %% [markdown]
# ###### The above 5 clusters shows the stocks which are similar in stock performance
