# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd

# %matplotlib inline

# %%
df = pd.read_csv("../csv_data/stocks.csv")

# %%
df.head()
# Out:
#          DATE      SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# 0  1491226200  2363.6101     42.3300     143.6800     129.6300      82.040
# 1  1491226260  2364.1001     42.3600     143.7000     130.3200      82.080
# 2  1491226320  2362.6799     42.3100     143.6901     130.2250      82.030
# 3  1491226380  2364.3101     42.3700     143.6400     130.0729      82.000
# 4  1491226440  2364.8501     42.5378     143.6600     129.8800      82.035
#
#    NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  ...  NYSE.WYN  NYSE.XEC  \
# 0    102.2300      85.2200       59.760       121.52  ...    84.370   119.035
# 1    102.1400      85.6500       59.840       121.48  ...    84.370   119.035
# 2    102.2125      85.5100       59.795       121.93  ...    84.585   119.260
# 3    102.1400      85.4872       59.620       121.44  ...    84.460   119.260
# 4    102.0600      85.7001       59.620       121.60  ...    84.470   119.610
#
# ...

# %%
df['DATE'].dtypes
# Out:
# dtype('int64')

# %%
df['DATE'] = pd.to_datetime(df['DATE'],unit='s')

# %%
df['DATE'].head()
# Out:
# 0   2017-04-03 13:30:00
# 1   2017-04-03 13:31:00
# 2   2017-04-03 13:32:00
# 3   2017-04-03 13:33:00
# 4   2017-04-03 13:34:00
# Name: DATE, dtype: datetime64[ns]

# %%
df.index = df['DATE']

# %%
df.head()
# Out:
#                                    DATE      SP500  NASDAQ.AAL  NASDAQ.AAPL  \
# DATE
# 2017-04-03 13:30:00 2017-04-03 13:30:00  2363.6101     42.3300     143.6800
# 2017-04-03 13:31:00 2017-04-03 13:31:00  2364.1001     42.3600     143.7000
# 2017-04-03 13:32:00 2017-04-03 13:32:00  2362.6799     42.3100     143.6901
# 2017-04-03 13:33:00 2017-04-03 13:33:00  2364.3101     42.3700     143.6400
# 2017-04-03 13:34:00 2017-04-03 13:34:00  2364.8501     42.5378     143.6600
#
#                      NASDAQ.ADBE  NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  \
# DATE
# 2017-04-03 13:30:00     129.6300      82.040    102.2300      85.2200
# 2017-04-03 13:31:00     130.3200      82.080    102.1400      85.6500
# 2017-04-03 13:32:00     130.2250      82.030    102.2125      85.5100
# 2017-04-03 13:33:00     130.0729      82.000    102.1400      85.4872
# 2017-04-03 13:34:00     129.8800      82.035    102.0600      85.7001
#
#                      NASDAQ.AKAM  NASDAQ.ALXN  ...  NYSE.WYN  NYSE.XEC  \
# ...

# %%
df.drop('DATE',axis = 1,inplace=True)

# %%
df.head()
# Out:
#                          SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  \
# DATE
# 2017-04-03 13:30:00  2363.6101     42.3300     143.6800     129.6300
# 2017-04-03 13:31:00  2364.1001     42.3600     143.7000     130.3200
# 2017-04-03 13:32:00  2362.6799     42.3100     143.6901     130.2250
# 2017-04-03 13:33:00  2364.3101     42.3700     143.6400     130.0729
# 2017-04-03 13:34:00  2364.8501     42.5378     143.6600     129.8800
#
#                      NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  \
# DATE
# 2017-04-03 13:30:00      82.040    102.2300      85.2200       59.760
# 2017-04-03 13:31:00      82.080    102.1400      85.6500       59.840
# 2017-04-03 13:32:00      82.030    102.2125      85.5100       59.795
# 2017-04-03 13:33:00      82.000    102.1400      85.4872       59.620
# 2017-04-03 13:34:00      82.035    102.0600      85.7001       59.620
#
#                      NASDAQ.ALXN  NASDAQ.AMAT  ...  NYSE.WYN  NYSE.XEC  \
# ...

# %%
df.tail()
# Out:
#                        SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  \
# DATE
# 2017-08-31 19:56:00  2472.22       44.72       164.11      155.090
# 2017-08-31 19:57:00  2471.77       44.73       164.12      155.160
# 2017-08-31 19:58:00  2470.03       44.74       164.01      155.065
# 2017-08-31 19:59:00  2471.49       44.71       163.88      154.960
# 2017-08-31 20:00:00  2471.49       44.74       163.98      155.160
#
#                      NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  \
# DATE
# 2017-08-31 19:56:00       83.67     106.565       114.49       47.150
# 2017-08-31 19:57:00       83.65     106.590       114.52       47.150
# 2017-08-31 19:58:00       83.62     106.520       114.47       47.150
# 2017-08-31 19:59:00       83.58     106.400       114.33       47.135
# 2017-08-31 20:00:00       83.69     106.470       114.46       47.150
#
#                      NASDAQ.ALXN  NASDAQ.AMAT  ...  NYSE.WYN  NYSE.XEC  \
# DATE                                           ...
# ...

# %%
from sklearn.cluster import KMeans

# %%
x=df.iloc[:,:]

# %%
x
# Out:
#                      NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# DATE
# 2017-04-03 13:30:00     42.3300     143.6800     129.6300      82.040
# 2017-04-03 13:31:00     42.3600     143.7000     130.3200      82.080
# 2017-04-03 13:32:00     42.3100     143.6901     130.2250      82.030
# 2017-04-03 13:33:00     42.3700     143.6400     130.0729      82.000
# 2017-04-03 13:34:00     42.5378     143.6600     129.8800      82.035
# ...                         ...          ...          ...         ...
# 2017-08-31 19:56:00     44.7200     164.1100     155.0900      83.670
# 2017-08-31 19:57:00     44.7300     164.1200     155.1600      83.650
# 2017-08-31 19:58:00     44.7400     164.0100     155.0650      83.620
# 2017-08-31 19:59:00     44.7100     163.8800     154.9600      83.580
# 2017-08-31 20:00:00     44.7400     163.9800     155.1600      83.690
#
#                      NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  \
# DATE
# ...

# %%
wcss=[]
for i in range(1,15):
    kmean=KMeans(n_clusters=i,init='k-means++',random_state=30)
    kmean.fit(x)
    wcss.append(kmean.inertia_)

# %%
plt.plot(range(1,15)  , wcss)

# %%
kmean1= KMeans(n_clusters=5 ,init = 'k-means++' , random_state=30)
kmean1.fit_predict(x)
# Out:
# array([4, 4, 4, ..., 0, 0, 0])

# %%
x['cluster number'] = kmean1.fit_predict(x)

# %%
x
# Out:
#                          SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  \
# DATE
# 2017-04-03 13:30:00  2363.6101     42.3300     143.6800     129.6300
# 2017-04-03 13:31:00  2364.1001     42.3600     143.7000     130.3200
# 2017-04-03 13:32:00  2362.6799     42.3100     143.6901     130.2250
# 2017-04-03 13:33:00  2364.3101     42.3700     143.6400     130.0729
# 2017-04-03 13:34:00  2364.8501     42.5378     143.6600     129.8800
# ...                        ...         ...          ...          ...
# 2017-08-31 19:56:00  2472.2200     44.7200     164.1100     155.0900
# 2017-08-31 19:57:00  2471.7700     44.7300     164.1200     155.1600
# 2017-08-31 19:58:00  2470.0300     44.7400     164.0100     155.0650
# 2017-08-31 19:59:00  2471.4900     44.7100     163.8800     154.9600
# 2017-08-31 20:00:00  2471.4900     44.7400     163.9800     155.1600
#
#                      NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  \
# DATE
# ...

# %%
x[x['cluster number'] ==4]
# Out:
#                          SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  \
# DATE
# 2017-04-03 13:30:00  2363.6101     42.3300     143.6800     129.6300
# 2017-04-03 13:31:00  2364.1001     42.3600     143.7000     130.3200
# 2017-04-03 13:32:00  2362.6799     42.3100     143.6901     130.2250
# 2017-04-03 13:33:00  2364.3101     42.3700     143.6400     130.0729
# 2017-04-03 13:34:00  2364.8501     42.5378     143.6600     129.8800
# ...                        ...         ...          ...          ...
# 2017-04-27 18:40:00  2390.1899     43.7400     143.7900     133.4700
# 2017-04-27 18:41:00  2389.8999     43.7700     143.7700     133.4300
# 2017-04-27 18:42:00  2390.3201     43.7550     143.7400     133.4250
# 2017-04-27 18:43:00  2390.5901     43.7550     143.7835     133.4700
# 2017-04-27 18:44:00  2390.4600     43.8200     143.7950     133.4700
#
#                      NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  \
# DATE
# ...

# %%
x[x['cluster number'] ==3]
# Out:
#                          SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  \
# DATE
# 2017-05-23 13:30:00  2398.4099     46.2700     154.9000      139.160
# 2017-05-23 13:31:00  2396.8601     46.3115     154.6320      139.376
# 2017-05-23 13:32:00  2397.0200     46.1100     154.0000      139.490
# 2017-05-23 13:33:00  2397.0901     46.0650     154.1800      139.550
# 2017-05-23 13:34:00  2396.3799     46.1500     154.2000      139.250
# ...                        ...         ...          ...          ...
# 2017-07-07 15:30:00  2421.7400     53.0250     143.9850      142.130
# 2017-07-07 15:31:00  2421.7100     53.0400     143.9600      142.040
# 2017-07-07 15:32:00  2421.2700     53.0100     144.0221      142.000
# 2017-07-07 15:33:00  2421.9800     53.0550     144.0300      142.060
# 2017-07-07 15:34:00  2422.4199     53.0500     144.0700      142.200
#
#                      NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  \
# DATE
# ...

# %%
x[x['cluster number'] ==2]
# Out:
#                          SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  \
# DATE
# 2017-07-07 15:35:00  2423.3201      53.140     144.0870     142.3200
# 2017-07-07 15:36:00  2423.1899      53.180     144.1400     142.3800
# 2017-07-07 15:37:00  2423.5801      53.090     144.0700     142.3450
# 2017-07-07 15:38:00  2423.5500      53.060     144.0600     142.3000
# 2017-07-07 15:39:00  2423.2700      53.100     144.1144     142.3554
# ...                        ...         ...          ...          ...
# 2017-08-08 19:56:00  2473.0500      49.985     159.8500     147.7700
# 2017-08-08 19:57:00  2473.7700      49.980     159.8850     147.7300
# 2017-08-08 19:58:00  2474.3101      50.000     159.9900     147.8450
# 2017-08-08 19:59:00  2474.8601      50.010     159.9700     147.7900
# 2017-08-08 20:00:00  2474.8601      50.000     160.0800     147.8100
#
#                      NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  \
# DATE
# ...

# %%
x[x['cluster number'] ==1]
# Out:
#                          SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  \
# DATE
# 2017-04-27 18:45:00  2390.6399      43.850       143.80     133.4600
# 2017-04-27 18:46:00  2390.5701      43.845       143.77     133.4565
# 2017-04-27 18:47:00  2390.5701      43.800       143.77     133.4580
# 2017-04-27 18:48:00  2390.8501      43.795       143.78     133.4500
# 2017-04-27 18:49:00  2390.5901      43.820       143.79     133.4300
# ...                        ...         ...          ...          ...
# 2017-05-22 19:56:00  2395.0200      46.205       154.00     138.9250
# 2017-05-22 19:57:00  2394.6599      46.200       153.97     138.9200
# 2017-05-22 19:58:00  2394.0300      46.190       153.94     138.9000
# 2017-05-22 19:59:00  2393.8899      46.200       153.90     138.8500
# 2017-05-22 20:00:00  2393.8899      46.210       153.99     138.8600
#
#                      NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  \
# DATE
# ...

# %%
x[x['cluster number'] ==0]
# Out:
#                          SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  \
# DATE
# 2017-08-09 13:30:00  2465.4399     49.7400       159.25      146.680
# 2017-08-09 13:31:00  2464.7400     49.6400       159.71      146.860
# 2017-08-09 13:32:00  2465.5701     49.5271       159.86      146.560
# 2017-08-09 13:33:00  2467.8401     49.4950       159.64      146.660
# 2017-08-09 13:34:00  2468.0901     49.2800       159.86      146.700
# ...                        ...         ...          ...          ...
# 2017-08-31 19:56:00  2472.2200     44.7200       164.11      155.090
# 2017-08-31 19:57:00  2471.7700     44.7300       164.12      155.160
# 2017-08-31 19:58:00  2470.0300     44.7400       164.01      155.065
# 2017-08-31 19:59:00  2471.4900     44.7100       163.88      154.960
# 2017-08-31 20:00:00  2471.4900     44.7400       163.98      155.160
#
#                      NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  \
# DATE
# ...

# %%
from sklearn.cluster import MiniBatchKMeans
minibatch_kmean = MiniBatchKMeans(n_clusters=5)
minibatch_kmean.fit(x)
# Out:
# d:\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1043: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 3072 or by setting the environment variable OMP_NUM_THREADS=4
#   warnings.warn(
# MiniBatchKMeans(n_clusters=5)

# %%
x['MiniBatch_cluster number']=minibatch_kmean.fit_predict(x)
# Out:
# d:\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1043: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 3072 or by setting the environment variable OMP_NUM_THREADS=4
#   warnings.warn(

# %%
from  sklearn.cluster import DBSCAN

# %%
x
# Out:
#                          SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  \
# DATE
# 2017-04-03 13:30:00  2363.6101     42.3300     143.6800     129.6300
# 2017-04-03 13:31:00  2364.1001     42.3600     143.7000     130.3200
# 2017-04-03 13:32:00  2362.6799     42.3100     143.6901     130.2250
# 2017-04-03 13:33:00  2364.3101     42.3700     143.6400     130.0729
# 2017-04-03 13:34:00  2364.8501     42.5378     143.6600     129.8800
# ...                        ...         ...          ...          ...
# 2017-08-31 19:56:00  2472.2200     44.7200     164.1100     155.0900
# 2017-08-31 19:57:00  2471.7700     44.7300     164.1200     155.1600
# 2017-08-31 19:58:00  2470.0300     44.7400     164.0100     155.0650
# 2017-08-31 19:59:00  2471.4900     44.7100     163.8800     154.9600
# 2017-08-31 20:00:00  2471.4900     44.7400     163.9800     155.1600
#
#                      NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  \
# DATE
# ...

# %%
DBSCAN(eps=1, min_samples=3)
